# %%
import pandas as pd
import re

# %%
data_str = """#                       fl_choice test_type num_subjects num_timepoints  power           se power_01         se01
# experiment_output            6 Inclusion         1000             90 0.0588  0.003326937   0.1122  0.004463433
# experiment_output.1          7 Inclusion         1000             90 0.7934  0.005725669   0.8698  0.004759159
# experiment_output.2          8 Inclusion         1000             90 0.9988 0.0004896039   0.9994 0.0003463062
# experiment_output.3          9 Inclusion         1000             90      1            0        1            0
# experiment_output.4         10 Inclusion         1000             90      1            0        1            0
# experiment_output.5          6 Inclusion          500             90 0.0606  0.003374245   0.1116  0.004452986
# experiment_output.6          7 Inclusion          500             90 0.5038  0.007070864   0.6302  0.006827122
# experiment_output.7          8 Inclusion          500             90 0.9504    0.0030705   0.9766   0.00213787
# experiment_output.8          9 Inclusion          500             90 0.9986 0.0005287797   0.9994 0.0003463062
# experiment_output.9         10 Inclusion          500             90      1            0        1            0
# experiment_output.10         6 Inclusion          300             90 0.0512  0.003117004   0.1028  0.004294931
# experiment_output.11         7 Inclusion          300             90 0.3506  0.006748031   0.4696  0.007057986
# experiment_output.12         8 Inclusion          300             90 0.7954  0.005705065   0.8736  0.004699426
# experiment_output.13         9 Inclusion          300             90 0.9596  0.002784523   0.9792  0.002018284
# experiment_output.14        10 Inclusion          300             90  0.994  0.001092154    0.998 0.0006318228
# experiment_output.15         6 Inclusion          100             90 0.0576  0.003294912   0.1098  0.004421402
# experiment_output.16         7 Inclusion          100             90  0.137  0.004862736   0.2302  0.005953284
# experiment_output.17         8 Inclusion          100             90  0.368  0.006820205   0.4854  0.007068053
# experiment_output.18         9 Inclusion          100             90  0.564  0.007012902   0.6926  0.006525416
# experiment_output.19        10 Inclusion          100             90 0.7408  0.006197021   0.8298  0.005314733
# experiment_output.20         6 Inclusion         1000            180 0.0606  0.003374245   0.1076  0.004382288
# experiment_output.21         7 Inclusion         1000            180  0.567  0.007007296   0.6784  0.006605656
# experiment_output.22         8 Inclusion         1000            180 0.9722  0.002324958   0.9866  0.001626065
# experiment_output.23         9 Inclusion         1000            180 0.9998   0.00019998   0.9998   0.00019998
# experiment_output.24        10 Inclusion         1000            180      1            0        1            0
# experiment_output.25         6 Inclusion          500            180 0.0574  0.003289536   0.1124  0.004466906
# experiment_output.26         7 Inclusion          500            180 0.3346  0.006672973    0.451  0.007037031
# experiment_output.27         8 Inclusion          500            180  0.782   0.00583911   0.8602  0.004904201
# experiment_output.28         9 Inclusion          500            180 0.9538  0.002968689   0.9776  0.002092761
# experiment_output.29        10 Inclusion          500            180   0.99  0.001407125   0.9956 0.0009360171
# experiment_output.30         6 Inclusion          300            180 0.0578  0.003300278   0.1092   0.00441079
# experiment_output.31         7 Inclusion          300            180 0.2224  0.005881126   0.3256  0.006626985
# experiment_output.32         8 Inclusion          300            180  0.564  0.007012902   0.6858  0.006564729
# experiment_output.33         9 Inclusion          300            180   0.81  0.005547973     0.88   0.00459565
# experiment_output.34        10 Inclusion          300            180 0.9192  0.003854124   0.9564  0.002887873
# experiment_output.35         6 Inclusion          100            180 0.0582  0.003310974   0.1074  0.004378704
# experiment_output.36         7 Inclusion          100            180 0.1106  0.004435485   0.1852   0.00549365
# experiment_output.37         8 Inclusion          100            180 0.2386   0.00602777   0.3498  0.006744479
# experiment_output.38         9 Inclusion          100            180 0.3806  0.006866493    0.506  0.007070559
# experiment_output.39        10 Inclusion          100            180 0.5106  0.007069479   0.6436  0.006773168"""

# %%
splits = data_str.split('\n')
data_rows = splits[1:]
header = splits[0]
header.split()
# Out:
# ['#',
#  'fl_choice',
#  'test_type',
#  'num_subjects',
#  'num_timepoints',
#  'power',
#  'se',
#  'power_01',
#  'se01']

# %%
data_rows[0][2:].split()
# Out:
# ['experiment_output',
#  '6',
#  'Inclusion',
#  '1000',
#  '90',
#  '0.0588',
#  '0.003326937',
#  '0.1122',
#  '0.004463433']

# %%
def val_from_idx(idx, val):
    if idx in {1, 3, 4}:
        return int(val)
    elif idx in {0, 2}:
        return val
    return float(val)
    
df = pd.DataFrame([[val_from_idx(idx,val) for idx, val in enumerate(data[2:].split())] for data in data_rows], columns=header.split())
df.sort_values(["num_timepoints", "num_subjects", "fl_choice"], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                        #  fl_choice  test_type  num_subjects  num_timepoints  \
# 0   experiment_output.15          6  Inclusion           100              90
# 1   experiment_output.16          7  Inclusion           100              90
# 2   experiment_output.17          8  Inclusion           100              90
# 3   experiment_output.18          9  Inclusion           100              90
# 4   experiment_output.19         10  Inclusion           100              90
# 5   experiment_output.10          6  Inclusion           300              90
# 6   experiment_output.11          7  Inclusion           300              90
# 7   experiment_output.12          8  Inclusion           300              90
# 8   experiment_output.13          9  Inclusion           300              90
# 9   experiment_output.14         10  Inclusion           300              90
# 10   experiment_output.5          6  Inclusion           500              90
# 11   experiment_output.6          7  Inclusion           500              90
# 12   experiment_output.7          8  Inclusion           500              90
# 13   experiment_output.8          9  Inclusion           500              90
# 14   experiment_output.9         10  Inclusion           500              90
# 15     experiment_output          6  Inclusion          1000              90
# 16   experiment_output.1          7  Inclusion          1000              90
# 17   experiment_output.2          8  Inclusion          1000              90
# 18   experiment_output.3          9  Inclusion          1000              90
# 19   experiment_output.4         10  Inclusion          1000              90
# 20  experiment_output.35          6  Inclusion           100             180
# 21  experiment_output.36          7  Inclusion           100             180
# 22  experiment_output.37          8  Inclusion           100             180
# 23  experiment_output.38          9  Inclusion           100             180
# 24  experiment_output.39         10  Inclusion           100             180
# 25  experiment_output.30          6  Inclusion           300             180
# 26  experiment_output.31          7  Inclusion           300             180
# 27  experiment_output.32          8  Inclusion           300             180
# 28  experiment_output.33          9  Inclusion           300             180
# 29  experiment_output.34         10  Inclusion           300             180
# 30  experiment_output.25          6  Inclusion           500             180
# 31  experiment_output.26          7  Inclusion           500             180
# 32  experiment_output.27          8  Inclusion           500             180
# 33  experiment_output.28          9  Inclusion           500             180
# 34  experiment_output.29         10  Inclusion           500             180
# 35  experiment_output.20          6  Inclusion          1000             180
# 36  experiment_output.21          7  Inclusion          1000             180
# 37  experiment_output.22          8  Inclusion          1000             180
# 38  experiment_output.23          9  Inclusion          1000             180
# 39  experiment_output.24         10  Inclusion          1000             180
#
#      power        se  power_01      se01
# 0   0.0576  0.003295    0.1098  0.004421
# 1   0.1370  0.004863    0.2302  0.005953
# 2   0.3680  0.006820    0.4854  0.007068
# 3   0.5640  0.007013    0.6926  0.006525
# 4   0.7408  0.006197    0.8298  0.005315
# 5   0.0512  0.003117    0.1028  0.004295
# 6   0.3506  0.006748    0.4696  0.007058
# 7   0.7954  0.005705    0.8736  0.004699
# 8   0.9596  0.002785    0.9792  0.002018
# 9   0.9940  0.001092    0.9980  0.000632
# 10  0.0606  0.003374    0.1116  0.004453
# 11  0.5038  0.007071    0.6302  0.006827
# 12  0.9504  0.003070    0.9766  0.002138
# 13  0.9986  0.000529    0.9994  0.000346
# 14  1.0000  0.000000    1.0000  0.000000
# 15  0.0588  0.003327    0.1122  0.004463
# 16  0.7934  0.005726    0.8698  0.004759
# 17  0.9988  0.000490    0.9994  0.000346
# 18  1.0000  0.000000    1.0000  0.000000
# 19  1.0000  0.000000    1.0000  0.000000
# 20  0.0582  0.003311    0.1074  0.004379
# 21  0.1106  0.004435    0.1852  0.005494
# 22  0.2386  0.006028    0.3498  0.006744
# 23  0.3806  0.006866    0.5060  0.007071
# 24  0.5106  0.007069    0.6436  0.006773
# 25  0.0578  0.003300    0.1092  0.004411
# 26  0.2224  0.005881    0.3256  0.006627
# 27  0.5640  0.007013    0.6858  0.006565
# 28  0.8100  0.005548    0.8800  0.004596
# 29  0.9192  0.003854    0.9564  0.002888
# 30  0.0574  0.003290    0.1124  0.004467
# 31  0.3346  0.006673    0.4510  0.007037
# 32  0.7820  0.005839    0.8602  0.004904
# 33  0.9538  0.002969    0.9776  0.002093
# 34  0.9900  0.001407    0.9956  0.000936
# 35  0.0606  0.003374    0.1076  0.004382
# 36  0.5670  0.007007    0.6784  0.006606
# 37  0.9722  0.002325    0.9866  0.001626
# 38  0.9998  0.000200    0.9998  0.000200
# 39  1.0000  0.000000    1.0000  0.000000

# %%
for idx, row in df[df["num_timepoints"] == 90].iterrows():
    print("{}\t{}\t{:.3f} ({:.3f})\t{:.3f} ({:.3f})".format(row["num_subjects"], row["fl_choice"], row["power"], row["se"], row["power_01"], row["se01"]))
# Out:
# 100	6	0.058 (0.003)	0.110 (0.004)
# 100	7	0.137 (0.005)	0.230 (0.006)
# 100	8	0.368 (0.007)	0.485 (0.007)
# 100	9	0.564 (0.007)	0.693 (0.007)
# 100	10	0.741 (0.006)	0.830 (0.005)
# 300	6	0.051 (0.003)	0.103 (0.004)
# 300	7	0.351 (0.007)	0.470 (0.007)
# 300	8	0.795 (0.006)	0.874 (0.005)
# 300	9	0.960 (0.003)	0.979 (0.002)
# 300	10	0.994 (0.001)	0.998 (0.001)
# 500	6	0.061 (0.003)	0.112 (0.004)
# 500	7	0.504 (0.007)	0.630 (0.007)
# 500	8	0.950 (0.003)	0.977 (0.002)
# 500	9	0.999 (0.001)	0.999 (0.000)
# 500	10	1.000 (0.000)	1.000 (0.000)
# 1000	6	0.059 (0.003)	0.112 (0.004)
# 1000	7	0.793 (0.006)	0.870 (0.005)
# 1000	8	0.999 (0.000)	0.999 (0.000)
# 1000	9	1.000 (0.000)	1.000 (0.000)
# 1000	10	1.000 (0.000)	1.000 (0.000)

# %%
Tstring = """# 1] "----------------"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n100/"
# Total Length (power): 0
# Total Length (power_01): 0[1] "NA(NA)    NA(NA)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n100_f7/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.058(0.007)    0.059(0.007)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n100_f8/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.144(0.011)    0.145(0.011)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n100_f9/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.24(0.014)    0.242(0.013)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n100_f10/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.35(0.015)    0.357(0.015)"
# [1] "================"
# [1] "----------------"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n300/"
# Total Length (power): 0
# Total Length (power_01): 0[1] "NA(NA)    NA(NA)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n300_f7/"
# Total Length (power): 950
# Total Length (power_01): 950[1] "0.102(0.01)    0.11(0.01)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n300_f8/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.467(0.016)    0.477(0.015)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n300_f9/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.697(0.015)    0.7(0.014)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n300_f10/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.78(0.013)    0.785(0.013)"
# [1] "================"
# [1] "----------------"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n500/"
# Total Length (power): 0
# Total Length (power_01): 0[1] "NA(NA)    NA(NA)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n500_f7/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.259(0.014)    0.263(0.014)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n500_f8/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.745(0.014)    0.75(0.013)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n500_f9/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.917(0.009)    0.917(0.009)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n500_f10/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.93(0.008)    0.93(0.008)"
# [1] "================"
# [1] "----------------"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n1000/"
# Total Length (power): 0
# Total Length (power_01): 0[1] "NA(NA)    NA(NA)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n1000_f7/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.573(0.016)    0.578(0.015)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n1000_f8/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.964(0.006)    0.966(0.006)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n1000_f9/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.996(0.002)    0.996(0.002)"
# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n1000_f10/"
# Total Length (power): 1000
# Total Length (power_01): 1000[1] "0.999(0.001)    0.999(0.001)"
# [1] "================\""""

# %%
pattern = r"_n(\d+)_f(\d+)/"
match = re.search(pattern, '# [1] "./hazel_final_table_output/final_table_output_power_shuffle_n1000_f10/"')
match
# Out:
# <re.Match object; span=(66, 77), match='_n1000_f10/'>

# %%
pattern1 = re.compile(r"_n(\d+)/")
pattern2 = re.compile(r"_n(\d+)_f(\d+)/")
pattern3 = re.compile(r"Total Length \(power_01\): \d+\[1\] \"(.*)\"")

new_set = False
n_value = -123
f_value = -456
for idx, line in enumerate(Tstring.split("\n")):
    match1 = pattern1.search(line)
    match2 = pattern2.search(line)
    match3 = pattern3.search(line)
    if not new_set:
        if "----------------" in line:
            new_set = True
        elif "Total Length (power_01):" in line:
            print("{}\t{}\t{}".format(n_value, f_value, match3.group(1)))
        elif match2:
            f_value = int(match2.group(2))
    elif new_set:
        if match1:
            n_value = int(match1.group(1))
            f_value = 6
            new_set = False
# Out:
# 100	6	NA(NA)    NA(NA)
# 100	7	0.058(0.007)    0.059(0.007)
# 100	8	0.144(0.011)    0.145(0.011)
# 100	9	0.24(0.014)    0.242(0.013)
# 100	10	0.35(0.015)    0.357(0.015)
# 300	6	NA(NA)    NA(NA)
# 300	7	0.102(0.01)    0.11(0.01)
# 300	8	0.467(0.016)    0.477(0.015)
# 300	9	0.697(0.015)    0.7(0.014)
# 300	10	0.78(0.013)    0.785(0.013)
# 500	6	NA(NA)    NA(NA)
# 500	7	0.259(0.014)    0.263(0.014)
# 500	8	0.745(0.014)    0.75(0.013)
# 500	9	0.917(0.009)    0.917(0.009)
# 500	10	0.93(0.008)    0.93(0.008)
# 1000	6	NA(NA)    NA(NA)
# 1000	7	0.573(0.016)    0.578(0.015)
# 1000	8	0.964(0.006)    0.966(0.006)
# 1000	9	0.996(0.002)    0.996(0.002)
# 1000	10	0.999(0.001)    0.999(0.001)
